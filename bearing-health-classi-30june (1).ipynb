# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/test-final/IR028_0.mat
# /kaggle/input/testing/109.mat
# /kaggle/input/testing/OR0076_2.mat
# /kaggle/input/bearing-data/B021_2.mat
# /kaggle/input/bearing-data/B028_3.mat
# /kaggle/input/bearing-data/IR007_3.mat
# /kaggle/input/bearing-data/IR014_3.mat
# /kaggle/input/bearing-data/OR00712_2.mat
# /kaggle/input/bearing-data/IR028_2.mat
# /kaggle/input/bearing-data/B014_3.mat
# /kaggle/input/bearing-data/IR014_0.mat
# /kaggle/input/bearing-data/IR007_2.mat
# /kaggle/input/bearing-data/OR0073_1.mat
# /kaggle/input/bearing-data/Normal_3.mat
# /kaggle/input/bearing-data/B021_1.mat
# /kaggle/input/bearing-data/B028_1.mat
# /kaggle/input/bearing-data/IR014_1.mat
# /kaggle/input/bearing-data/Normal_1.mat
# /kaggle/input/bearing-data/OR0076_1.mat
# /kaggle/input/bearing-data/B007_1.mat
# /kaggle/input/bearing-data/B014_0.mat
# /kaggle/input/bearing-data/OR0146_2.mat
# /kaggle/input/bearing-data/B014_1.mat
# /kaggle/input/bearing-data/OR0216_3.mat
# /kaggle/input/bearing-data/B028_0.mat
# /kaggle/input/bearing-data/OR02112_2.mat
# /kaggle/input/bearing-data/B007_3.mat
# /kaggle/input/bearing-data/OR0146_0.mat
# /kaggle/input/bearing-data/B007_2.mat
# /kaggle/input/bearing-data/OR0213_3.mat
# /kaggle/input/bearing-data/OR0213_1.mat
# /kaggle/input/bearing-data/IR021_0.mat
# /kaggle/input/bearing-data/IR028_1.mat
# /kaggle/input/bearing-data/B028_2.mat
# /kaggle/input/bearing-data/OR0213_0.mat
# /kaggle/input/bearing-data/OR0216_1.mat
# /kaggle/input/bearing-data/B014_2.mat
# /kaggle/input/bearing-data/OR0213_2.mat
# /kaggle/input/bearing-data/OR02112_0.mat
# /kaggle/input/bearing-data/OR0216_2.mat
# /kaggle/input/bearing-data/B021_3.mat
# /kaggle/input/bearing-data/Normal_2.mat
# /kaggle/input/bearing-data/IR014_2.mat
# /kaggle/input/bearing-data/IR021_2.mat
# /kaggle/input/bearing-data/B021_0.mat
# /kaggle/input/bearing-data/OR00712_1.mat
# /kaggle/input/bearing-data/OR0146_1.mat
# /kaggle/input/bearing-data/OR0216_0.mat
# /kaggle/input/bearing-data/OR00712_3.mat
# /kaggle/input/bearing-data/B007_0.mat
# /kaggle/input/bearing-data/OR0076_0.mat
# /kaggle/input/bearing-data/OR00712_0.mat
# /kaggle/input/bearing-data/IR007_0.mat
# /kaggle/input/bearing-data/OR0073_3.mat
# /kaggle/input/bearing-data/IR021_3.mat
# /kaggle/input/bearing-data/OR02112_3.mat
# /kaggle/input/bearing-data/IR021_1.mat
# /kaggle/input/bearing-data/IR007_1.mat
# /kaggle/input/bearing-data/Normal_0.mat
# /kaggle/input/bearing-data/IR028_3.mat
# /kaggle/input/bearing-data/OR0073_0.mat
# /kaggle/input/bearing-data/OR02112_1.mat
# /kaggle/input/bearing-data/OR0073_2.mat
# /kaggle/input/bearing-data/OR0076_3.mat
# /kaggle/input/bearing-data/OR0146_3.mat
# /kaggle/input/inference/135.mat

# %%
import numpy as np
import pandas as pd
import os
import glob
from tqdm import tqdm
from scipy.io import loadmat
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# --- Config ---
sampling_rate = 12000
window_sec = 5
out_shape = (128, 128)
data_path = "/kaggle/input/bearing-data"

# --- Label Mapper ---
def classify_file(filename):
    if "IR" in filename: return 1
    if "OR" in filename: return 2
    if "B0" in filename: return 3
    if "Normal" in filename or "97" in filename: return 0
    return -1

# --- Segment Signal ---
def segment_signal(signal, fs, window_sec):
    win_len = fs * window_sec
    return [signal[i:i+win_len] for i in range(0, len(signal), win_len) if len(signal[i:i+win_len]) == win_len]

# --- Spectrogram Conversion ---
def segment_to_spectrogram(segment, fs, out_shape):
    f, t, Sxx = spectrogram(segment, fs, nperseg=256, noverlap=128)
    Sxx_db = 10 * np.log10(Sxx + 1e-8)
    h, w = min(Sxx_db.shape[0], out_shape[0]), min(Sxx_db.shape[1], out_shape[1])
    out = np.zeros(out_shape)
    out[:h, :w] = Sxx_db[:h, :w]
    return out

# --- Augmentation Helpers ---
def amplitude_scaling(seg, scale_range=(0.8, 1.2)):
    scale = np.random.uniform(*scale_range)
    return seg * scale
def frequency_masking(spec, mask_height=100):
    spec = spec.copy()
    f0 = np.random.randint(0, spec.shape[0] - mask_height)
    spec[f0:f0 + mask_height, :] = np.min(spec)  # or set to 0
    return spec


# --- Load and Augment Dataset ---
X, y = [], []
mat_files = glob.glob(os.path.join(data_path, "*.mat"))

for filepath in tqdm(mat_files):
    try:
        label = classify_file(os.path.basename(filepath))
        if label == -1:
            continue

        data = loadmat(filepath)
        key = [k for k in data.keys() if "DE_time" in k][0]
        signal = data[key].ravel()
        segments = segment_signal(signal, sampling_rate, window_sec)

        for seg in segments:
            base_spec = segment_to_spectrogram(seg, sampling_rate, out_shape)

            # Original
            X.append(base_spec)
            y.append(label)

            # Gaussian Noise
            noisy = seg + np.random.normal(0, 0.08, size=seg.shape)
            X.append(segment_to_spectrogram(noisy, sampling_rate, out_shape))
            y.append(label)

            # Amplitude Scaled
            scaled = amplitude_scaling(seg)
            X.append(segment_to_spectrogram(scaled, sampling_rate, out_shape))
            y.append(label)

            # Frequency Masking
            masked_spec = frequency_masking(base_spec)
            X.append(masked_spec)
            y.append(label)

    except Exception as e:
        print(f"Error processing {filepath}: {e}")

X = np.array(X)[..., np.newaxis]
y = np.array(y)

print("Final dataset:")
print("Total samples:", X.shape[0])
print("Image shape:", X.shape[1:])
print("Label distribution:", pd.Series(y).value_counts().sort_index().to_dict())

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# --- Compute Class Weights ---
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# --- CNN Model Definition ---
model = tf.keras.Sequential([
    tf.keras.Input(shape=(128, 128, 1)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# --- Train Model ---
history = model.fit(X_train, y_train,
                    epochs=60,
                    batch_size=32,
                    validation_split=0.2,
                    class_weight=class_weight_dict,
                    verbose=1)

# --- Save Model ---
model.save("bearing_fault_cnn_model2.h5")  # Or use "bearing_fault_cnn_model" for SavedModel format

# --- Evaluate Model ---
y_pred = model.predict(X_test).argmax(axis=1)
accuracy = accuracy_score(y_test, y_pred)

print("\nTest Accuracy:", round(accuracy, 4))
print("Classification Report:\n", classification_report(y_test, y_pred))

# --- Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'IR', 'OR', 'Ball'],
            yticklabels=['Normal', 'IR', 'OR', 'Ball'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# --- Training History Plots ---
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 62/62 [00:01<00:00, 45.90it/s]
# Final dataset:
# Total samples: 576
# Image shape: (128, 128, 1)
# Label distribution: {0: 112, 1: 120, 2: 216, 3: 128}
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)                   │ (None, 128, 128, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_24 (MaxPooling2D)      │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_26               │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,288,516 (16.36 MB)
#  Trainable params: 4,288,068 (16.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.3873 - loss: 9.9073 - val_accuracy: 0.3370 - val_loss: 4.3441
# Epoch 2/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7002 - loss: 1.5342 - val_accuracy: 0.3478 - val_loss: 3.7542
# Epoch 3/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8273 - loss: 0.4517 - val_accuracy: 0.3370 - val_loss: 2.6363
# Epoch 4/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8306 - loss: 0.4640 - val_accuracy: 0.3478 - val_loss: 3.0462
# Epoch 5/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8900 - loss: 0.2690 - val_accuracy: 0.3696 - val_loss: 2.3006
# Epoch 6/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8427 - loss: 0.2883 - val_accuracy: 0.5000 - val_loss: 1.2368
# Epoch 7/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8882 - loss: 0.2373 - val_accuracy: 0.4457 - val_loss: 1.0566
# Epoch 8/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9104 - loss: 0.1951 - val_accuracy: 0.5435 - val_loss: 1.0356
# Epoch 9/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8858 - loss: 0.1995 - val_accuracy: 0.5652 - val_loss: 0.9111
# Epoch 10/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9289 - loss: 0.1620 - val_accuracy: 0.5217 - val_loss: 0.9624
# Epoch 11/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9453 - loss: 0.1436 - val_accuracy: 0.5217 - val_loss: 1.0785
# Epoch 12/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9200 - loss: 0.1743 - val_accuracy: 0.5870 - val_loss: 0.9109
# Epoch 13/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9286 - loss: 0.3063 - val_accuracy: 0.7826 - val_loss: 0.5603
# Epoch 14/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9555 - loss: 0.1319 - val_accuracy: 0.8804 - val_loss: 0.4277
# Epoch 15/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9337 - loss: 0.1595 - val_accuracy: 0.8587 - val_loss: 0.4462
# Epoch 16/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9475 - loss: 0.1319 - val_accuracy: 0.8478 - val_loss: 0.4304
# Epoch 17/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9306 - loss: 0.1489 - val_accuracy: 0.8696 - val_loss: 0.4309
# Epoch 18/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9386 - loss: 0.1504 - val_accuracy: 0.8261 - val_loss: 0.4885
# Epoch 19/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9454 - loss: 0.1142 - val_accuracy: 0.8587 - val_loss: 0.4286
# Epoch 20/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9367 - loss: 0.1060 - val_accuracy: 0.8370 - val_loss: 0.4517
# Epoch 21/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9620 - loss: 0.1019 - val_accuracy: 0.8261 - val_loss: 0.5016
# Epoch 22/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9914 - loss: 0.0551 - val_accuracy: 0.8587 - val_loss: 0.6038
# Epoch 23/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9544 - loss: 0.1119 - val_accuracy: 0.9022 - val_loss: 0.3639
# Epoch 24/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9626 - loss: 0.0881 - val_accuracy: 0.8913 - val_loss: 0.3074
# Epoch 25/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9677 - loss: 0.0588 - val_accuracy: 0.8587 - val_loss: 0.4391
# Epoch 26/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9637 - loss: 0.0708 - val_accuracy: 0.7283 - val_loss: 0.8237
# Epoch 27/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9381 - loss: 0.1007 - val_accuracy: 0.9022 - val_loss: 0.2387
# Epoch 28/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9610 - loss: 0.0942 - val_accuracy: 0.8804 - val_loss: 0.3594
# Epoch 29/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9885 - loss: 0.0375 - val_accuracy: 0.9348 - val_loss: 0.3403
# Epoch 30/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9902 - loss: 0.0276 - val_accuracy: 0.8696 - val_loss: 0.3665
# Epoch 31/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9777 - loss: 0.0467 - val_accuracy: 0.8696 - val_loss: 0.3855
# Epoch 32/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9731 - loss: 0.0482 - val_accuracy: 0.8913 - val_loss: 0.2893
# Epoch 33/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9856 - loss: 0.0280 - val_accuracy: 0.9348 - val_loss: 0.2829
# Epoch 34/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9973 - loss: 0.0120 - val_accuracy: 0.9565 - val_loss: 0.2858
# Epoch 35/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9900 - loss: 0.0206 - val_accuracy: 0.9130 - val_loss: 0.3728
# Epoch 36/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9865 - loss: 0.0258 - val_accuracy: 0.8913 - val_loss: 0.3674
# Epoch 37/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0199 - val_accuracy: 0.9239 - val_loss: 0.3365
# Epoch 38/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9887 - loss: 0.0274 - val_accuracy: 0.8804 - val_loss: 0.3627
# Epoch 39/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9903 - loss: 0.0192 - val_accuracy: 0.8913 - val_loss: 0.4624
# Epoch 40/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9778 - loss: 0.0468 - val_accuracy: 0.8913 - val_loss: 0.3033
# Epoch 41/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9926 - loss: 0.0271 - val_accuracy: 0.9239 - val_loss: 0.3097
# Epoch 42/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9805 - loss: 0.0410 - val_accuracy: 0.8696 - val_loss: 0.4020
# Epoch 43/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9810 - loss: 0.0399 - val_accuracy: 0.9130 - val_loss: 0.4847
# Epoch 44/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9853 - loss: 0.0343 - val_accuracy: 0.8804 - val_loss: 0.5562
# Epoch 45/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9746 - loss: 0.0530 - val_accuracy: 0.9130 - val_loss: 0.4021
# Epoch 46/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9813 - loss: 0.0569 - val_accuracy: 0.8913 - val_loss: 0.6183
# Epoch 47/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9907 - loss: 0.0273 - val_accuracy: 0.8478 - val_loss: 0.7774
# Epoch 48/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9917 - loss: 0.0191 - val_accuracy: 0.8696 - val_loss: 0.6946
# Epoch 49/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9838 - loss: 0.0152 - val_accuracy: 0.9130 - val_loss: 0.5550
# Epoch 50/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9974 - loss: 0.0089 - val_accuracy: 0.9130 - val_loss: 0.5227
# Epoch 51/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9894 - loss: 0.0337 - val_accuracy: 0.8913 - val_loss: 0.6132
# Epoch 52/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9973 - loss: 0.0077 - val_accuracy: 0.8696 - val_loss: 0.9193
# Epoch 53/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9938 - loss: 0.0223 - val_accuracy: 0.8478 - val_loss: 0.9906
# Epoch 54/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9938 - loss: 0.0200 - val_accuracy: 0.9130 - val_loss: 0.5134
# Epoch 55/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9947 - loss: 0.0202 - val_accuracy: 0.8913 - val_loss: 0.4480
# Epoch 56/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9931 - loss: 0.0164 - val_accuracy: 0.9022 - val_loss: 0.4226
# Epoch 57/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9957 - loss: 0.0217 - val_accuracy: 0.8696 - val_loss: 0.6195
# Epoch 58/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9749 - loss: 0.1013 - val_accuracy: 0.8370 - val_loss: 0.3536
# Epoch 59/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9926 - loss: 0.0423 - val_accuracy: 0.8804 - val_loss: 0.3458
# Epoch 60/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9947 - loss: 0.0302 - val_accuracy: 0.9239 - val_loss: 0.3226
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step
#
# Test Accuracy: 0.9224
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        23
#            1       0.83      0.83      0.83        24
#            2       0.95      0.95      0.95        43
#            3       0.89      0.92      0.91        26
#
#     accuracy                           0.92       116
#    macro avg       0.92      0.92      0.92       116
# weighted avg       0.92      0.92      0.92       116

# %%
import numpy as np
import pandas as pd
import os
import glob
from tqdm import tqdm
from scipy.io import loadmat
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

# --- Config ---
sampling_rate = 12000
window_sec = 5
out_shape = (256, 256)
data_path = "/kaggle/input/bearing-data"

# --- Label Mapper ---
def classify_file(filename):
    if "IR" in filename: return 1
    if "OR" in filename: return 2
    if "B0" in filename: return 3
    if "Normal" in filename or "97" in filename: return 0
    return -1

# --- Segment Signal ---
def segment_signal(signal, fs, window_sec):
    win_len = fs * window_sec
    return [signal[i:i+win_len] for i in range(0, len(signal), win_len) if len(signal[i:i+win_len]) == win_len]

# --- Spectrogram Conversion ---
def segment_to_spectrogram(segment, fs, out_shape):
    f, t, Sxx = spectrogram(segment, fs, nperseg=256, noverlap=128)
    Sxx_db = 10 * np.log10(Sxx + 1e-8)
    h, w = min(Sxx_db.shape[0], out_shape[0]), min(Sxx_db.shape[1], out_shape[1])
    out = np.zeros(out_shape)
    out[:h, :w] = Sxx_db[:h, :w]
    return out
def add_rms_scaled_noise(signal, noise_ratio=0.1):
    rms = np.sqrt(np.mean(signal**2))
    noise = np.random.normal(0, noise_ratio * rms, size=signal.shape)
    return signal + noise

# --- Augmentation Helpers ---
def amplitude_scaling(seg, scale_range=(0.8,1.2)):
    scale = np.random.uniform(*scale_range)
    return seg * scale
    
def frequency_masking(spec, num_masks=1, freq_masking_max_percentage=0.15):
    spec = spec.copy()
    num_freqs = spec.shape[0]
    for _ in range(num_masks):
        f = int(np.random.uniform(0.0, freq_masking_max_percentage) * num_freqs)
        f0 = np.random.randint(0, num_freqs - f)
        spec[f0:f0 + f, :] = 0
    return spec


# --- Load and Augment Dataset ---
X, y = [], []
mat_files = glob.glob(os.path.join(data_path, "*.mat"))

for filepath in tqdm(mat_files):
    try:
        label = classify_file(os.path.basename(filepath))
        if label == -1:
            continue

        data = loadmat(filepath)
        key = [k for k in data.keys() if "DE_time" in k][0]
        signal = data[key].ravel()
        segments = segment_signal(signal, sampling_rate, window_sec)

        for seg in segments:
            base_spec = segment_to_spectrogram(seg, sampling_rate, out_shape)

            # Original
            X.append(base_spec)
            y.append(label)

            # Gaussian Noise
            noisy = add_rms_scaled_noise(seg, noise_ratio=0.1)

            X.append(segment_to_spectrogram(noisy, sampling_rate, out_shape))
            y.append(label)

            # Amplitude Scaled
            scaled = amplitude_scaling(seg)
            X.append(segment_to_spectrogram(scaled, sampling_rate, out_shape))
            y.append(label)

            # Frequency Masking
            masked_spec = frequency_masking(base_spec)
            X.append(masked_spec)
            y.append(label)

    except Exception as e:
        print(f"Error processing {filepath}: {e}")

X = np.array(X)[..., np.newaxis]
y = np.array(y)

print("Final dataset:")
print("Total samples:", X.shape[0])
print("Image shape:", X.shape[1:])
print("Label distribution:", pd.Series(y).value_counts().sort_index().to_dict())

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# --- Compute Class Weights ---
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# --- CNN Model Definition ---
model = tf.keras.Sequential([
    tf.keras.Input(shape=(256, 256, 1)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

# --- Train Model ---
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2,
                    class_weight=class_weight_dict,
                    verbose=1,
                    callbacks=[early_stop])

# --- Save Model ---
model.save("bearing_fault_cnn_model2.h5")  # Or use "bearing_fault_cnn_model" for SavedModel format

# --- Evaluate Model ---
y_pred = model.predict(X_test).argmax(axis=1)
accuracy = accuracy_score(y_test, y_pred)

print("\nTest Accuracy:", round(accuracy, 4))
print("Classification Report:\n", classification_report(y_test, y_pred))

# --- Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'IR', 'OR', 'Ball'],
            yticklabels=['Normal', 'IR', 'OR', 'Ball'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# --- Training History Plots ---
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 62/62 [00:01<00:00, 38.41it/s]
# Final dataset:
# Total samples: 576
# Image shape: (256, 256, 1)
# Label distribution: {0: 112, 1: 120, 2: 216, 3: 128}
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 256, 256, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256, 256, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 128, 128, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 128, 128, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 64, 64, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │      16,777,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,871,428 (64.36 MB)
#  Trainable params: 16,870,980 (64.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.3016 - loss: 25.2683 - val_accuracy: 0.1957 - val_loss: 6.6027
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4625 - loss: 3.6492 - val_accuracy: 0.1739 - val_loss: 6.6879
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5880 - loss: 1.5152 - val_accuracy: 0.1739 - val_loss: 6.1101
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4629 - loss: 1.2561 - val_accuracy: 0.2283 - val_loss: 2.3666
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5531 - loss: 0.8687 - val_accuracy: 0.4674 - val_loss: 1.2335
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6384 - loss: 0.8375 - val_accuracy: 0.3152 - val_loss: 1.2669
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6706 - loss: 0.8268 - val_accuracy: 0.3696 - val_loss: 1.1618
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6707 - loss: 0.8484 - val_accuracy: 0.2174 - val_loss: 1.4279
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6649 - loss: 0.7955 - val_accuracy: 0.2391 - val_loss: 2.2799
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6907 - loss: 0.7411 - val_accuracy: 0.2717 - val_loss: 2.3637
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6954 - loss: 0.7344 - val_accuracy: 0.3152 - val_loss: 2.5124
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7010 - loss: 0.6700 - val_accuracy: 0.3370 - val_loss: 2.1510
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7059 - loss: 0.7018 - val_accuracy: 0.3370 - val_loss: 1.8204
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7059 - loss: 0.6916 - val_accuracy: 0.3261 - val_loss: 2.1702
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7244 - loss: 0.7009 - val_accuracy: 0.5652 - val_loss: 1.1360
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7393 - loss: 0.6585 - val_accuracy: 0.6848 - val_loss: 0.9714
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7264 - loss: 0.7066 - val_accuracy: 0.6087 - val_loss: 0.9187
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7017 - loss: 0.6840 - val_accuracy: 0.5543 - val_loss: 0.9527
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7188 - loss: 0.6932 - val_accuracy: 0.6304 - val_loss: 0.9312
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7761 - loss: 0.5996 - val_accuracy: 0.7174 - val_loss: 0.9027
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7995 - loss: 0.5536 - val_accuracy: 0.6304 - val_loss: 0.8195
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6807 - loss: 0.5510 - val_accuracy: 0.8261 - val_loss: 0.6201
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8194 - loss: 0.4434 - val_accuracy: 0.8804 - val_loss: 0.4753
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8455 - loss: 0.4074 - val_accuracy: 0.8913 - val_loss: 0.5514
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8311 - loss: 0.4003 - val_accuracy: 0.9130 - val_loss: 0.5376
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8730 - loss: 0.2741 - val_accuracy: 0.8370 - val_loss: 0.4741
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8831 - loss: 0.3176 - val_accuracy: 0.5870 - val_loss: 1.0446
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7834 - loss: 0.3605 - val_accuracy: 0.9022 - val_loss: 0.3399
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8668 - loss: 0.3520 - val_accuracy: 0.8587 - val_loss: 0.3900
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8560 - loss: 0.3285 - val_accuracy: 0.9457 - val_loss: 0.2506
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8922 - loss: 0.2573 - val_accuracy: 0.9130 - val_loss: 0.2854
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8954 - loss: 0.2274 - val_accuracy: 0.9674 - val_loss: 0.2571
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9137 - loss: 0.1953 - val_accuracy: 0.9457 - val_loss: 0.2248
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9402 - loss: 0.1902 - val_accuracy: 0.9783 - val_loss: 0.2225
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9204 - loss: 0.1500 - val_accuracy: 0.9565 - val_loss: 0.2097
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9155 - loss: 0.2341 - val_accuracy: 0.8152 - val_loss: 0.6821
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8872 - loss: 0.2224 - val_accuracy: 0.8043 - val_loss: 1.0048
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8769 - loss: 0.3431 - val_accuracy: 0.8587 - val_loss: 0.3400
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8790 - loss: 0.2952 - val_accuracy: 0.9783 - val_loss: 0.0711
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8820 - loss: 0.2267 - val_accuracy: 0.9239 - val_loss: 0.3124
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8841 - loss: 0.2243 - val_accuracy: 0.8587 - val_loss: 0.3069
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9104 - loss: 0.2019 - val_accuracy: 0.9674 - val_loss: 0.1478
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9173 - loss: 0.1774 - val_accuracy: 0.9783 - val_loss: 0.1125
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9274 - loss: 0.1540 - val_accuracy: 0.9783 - val_loss: 0.0915
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9139 - loss: 0.1577 - val_accuracy: 0.9674 - val_loss: 0.1287
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9297 - loss: 0.1340 - val_accuracy: 0.9674 - val_loss: 0.1047
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9372 - loss: 0.1434 - val_accuracy: 0.9783 - val_loss: 0.0691
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9355 - loss: 0.1175 - val_accuracy: 0.9891 - val_loss: 0.0431
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9513 - loss: 0.1277 - val_accuracy: 0.9891 - val_loss: 0.0531
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9671 - loss: 0.0900 - val_accuracy: 0.9891 - val_loss: 0.0333
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9123 - loss: 0.1497 - val_accuracy: 0.9891 - val_loss: 0.0421
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9199 - loss: 0.1454 - val_accuracy: 0.9891 - val_loss: 0.0443
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8873 - loss: 0.2242 - val_accuracy: 0.9891 - val_loss: 0.0539
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9232 - loss: 0.1418 - val_accuracy: 0.9783 - val_loss: 0.1211
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9084 - loss: 0.1860 - val_accuracy: 0.9783 - val_loss: 0.1841
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9049 - loss: 0.2121 - val_accuracy: 0.9783 - val_loss: 0.1973
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9431 - loss: 0.1253 - val_accuracy: 0.9783 - val_loss: 0.1591
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9067 - loss: 0.1984 - val_accuracy: 0.9891 - val_loss: 0.0424
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9494 - loss: 0.1496 - val_accuracy: 0.9239 - val_loss: 0.1775
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9561 - loss: 0.0893 - val_accuracy: 0.9674 - val_loss: 0.1413
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9612 - loss: 0.0893 - val_accuracy: 0.9891 - val_loss: 0.0681
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9462 - loss: 0.1156 - val_accuracy: 0.9565 - val_loss: 0.1863
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9530 - loss: 0.0975 - val_accuracy: 0.9891 - val_loss: 0.0897
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9530 - loss: 0.0829 - val_accuracy: 0.9891 - val_loss: 0.0682
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9786 - loss: 0.0561 - val_accuracy: 0.9891 - val_loss: 0.0609
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step
#
# Test Accuracy: 0.9569
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        23
#            1       1.00      0.96      0.98        24
#            2       0.95      0.95      0.95        43
#            3       0.92      0.92      0.92        26
#
#     accuracy                           0.96       116
#    macro avg       0.96      0.96      0.96       116
# weighted avg       0.96      0.96      0.96       116

# %%
import numpy as np
import pandas as pd
import os
import glob
from tqdm import tqdm
from scipy.io import loadmat
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

# --- Config ---
sampling_rate = 12000
window_sec = 5
out_shape = (128, 128)
data_path = "/kaggle/input/bearing-data"

# --- Label Mapper ---
def classify_file(filename):
    if "IR" in filename: return 1
    if "OR" in filename: return 2
    if "B0" in filename: return 3
    if "Normal" in filename or "97" in filename: return 0
    return -1

# --- Segment Signal ---
def segment_signal(signal, fs, window_sec):
    win_len = fs * window_sec
    return [signal[i:i+win_len] for i in range(0, len(signal), win_len) if len(signal[i:i+win_len]) == win_len]

# --- Spectrogram Conversion ---
def segment_to_spectrogram(segment, fs, out_shape):
    f, t, Sxx = spectrogram(segment, fs, nperseg=256, noverlap=128)
    Sxx_db = 10 * np.log10(Sxx + 1e-8)
    h, w = min(Sxx_db.shape[0], out_shape[0]), min(Sxx_db.shape[1], out_shape[1])
    out = np.zeros(out_shape)
    out[:h, :w] = Sxx_db[:h, :w]
    return out
def add_rms_scaled_noise(signal, noise_ratio=0.2):
    rms = np.sqrt(np.mean(signal**2))
    noise = np.random.normal(0, noise_ratio * rms, size=signal.shape)
    return signal + noise

# --- Augmentation Helpers ---
def amplitude_scaling(seg, scale_range=(0.4,2.0)):
    scale = np.random.uniform(*scale_range)
    return seg * scale
    
def frequency_masking(spec, num_masks=1, freq_masking_max_percentage=0.15):
    spec = spec.copy()
    num_freqs = spec.shape[0]
    for _ in range(num_masks):
        f = int(np.random.uniform(0.0, freq_masking_max_percentage) * num_freqs)
        f0 = np.random.randint(0, num_freqs - f)
        spec[f0:f0 + f, :] = 0
    return spec


# --- Load and Augment Dataset ---
X, y = [], []
mat_files = glob.glob(os.path.join(data_path, "*.mat"))

for filepath in tqdm(mat_files):
    try:
        label = classify_file(os.path.basename(filepath))
        if label == -1:
            continue

        data = loadmat(filepath)
        key = [k for k in data.keys() if "DE_time" in k][0]
        signal = data[key].ravel()
        segments = segment_signal(signal, sampling_rate, window_sec)

        for seg in segments:
            base_spec = segment_to_spectrogram(seg, sampling_rate, out_shape)

            # Original
            X.append(base_spec)
            y.append(label)

            # Gaussian Noise
            noisy = add_rms_scaled_noise(seg, noise_ratio=0.1)

            X.append(segment_to_spectrogram(noisy, sampling_rate, out_shape))
            y.append(label)

            # Amplitude Scaled
            scaled = amplitude_scaling(seg)
            X.append(segment_to_spectrogram(scaled, sampling_rate, out_shape))
            y.append(label)

            # Frequency Masking
            masked_spec = frequency_masking(base_spec)
            X.append(masked_spec)
            y.append(label)

    except Exception as e:
        print(f"Error processing {filepath}: {e}")

X = np.array(X)[..., np.newaxis]
y = np.array(y)

print("Final dataset:")
print("Total samples:", X.shape[0])
print("Image shape:", X.shape[1:])
print("Label distribution:", pd.Series(y).value_counts().sort_index().to_dict())

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# --- Compute Class Weights ---
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# --- CNN Model Definition ---
model = tf.keras.Sequential([
    tf.keras.Input(shape=(128, 128, 1)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# --- Train Model ---
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2,
                    class_weight=class_weight_dict,
                    verbose=1,
                    callbacks=[early_stop])

# --- Save Model ---
model.save("bearing_fault_cnn_model_new.h5")  # Or use "bearing_fault_cnn_model" for SavedModel format

# --- Evaluate Model ---
y_pred = model.predict(X_test).argmax(axis=1)
accuracy = accuracy_score(y_test, y_pred)

print("\nTest Accuracy:", round(accuracy, 4))
print("Classification Report:\n", classification_report(y_test, y_pred))

# --- Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'IR', 'OR', 'Ball'],
            yticklabels=['Normal', 'IR', 'OR', 'Ball'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# --- Training History Plots ---
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 62/62 [00:01<00:00, 45.41it/s]
# Final dataset:
# Total samples: 576
# Image shape: (128, 128, 1)
# Label distribution: {0: 112, 1: 120, 2: 216, 3: 128}
# Model: "sequential_48"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_144 (Conv2D)                  │ (None, 128, 128, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_144              │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_144 (MaxPooling2D)     │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_145 (Conv2D)                  │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_145              │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_145 (MaxPooling2D)     │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_146 (Conv2D)                  │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_146              │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_146 (MaxPooling2D)     │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_48 (Flatten)                 │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_96 (Dense)                     │ (None, 128)                 │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_48 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_97 (Dense)                     │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,288,516 (16.36 MB)
#  Trainable params: 4,288,068 (16.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - accuracy: 0.4274 - loss: 5.9706 - val_accuracy: 0.1957 - val_loss: 64.2303
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7435 - loss: 1.0189 - val_accuracy: 0.1739 - val_loss: 64.0233
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7506 - loss: 0.7722 - val_accuracy: 0.1739 - val_loss: 55.9157
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8583 - loss: 0.3640 - val_accuracy: 0.1739 - val_loss: 44.4071
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9331 - loss: 0.1961 - val_accuracy: 0.1739 - val_loss: 31.8632
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9258 - loss: 0.1712 - val_accuracy: 0.1739 - val_loss: 21.1544
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9657 - loss: 0.0882 - val_accuracy: 0.1848 - val_loss: 18.1416
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9728 - loss: 0.0886 - val_accuracy: 0.1957 - val_loss: 12.4724
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9728 - loss: 0.0919 - val_accuracy: 0.1957 - val_loss: 11.2087
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9626 - loss: 0.1020 - val_accuracy: 0.2935 - val_loss: 6.8001
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9831 - loss: 0.0529 - val_accuracy: 0.3478 - val_loss: 4.2950
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9867 - loss: 0.0308 - val_accuracy: 0.4239 - val_loss: 2.8801
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9866 - loss: 0.0469 - val_accuracy: 0.5326 - val_loss: 1.7980
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9790 - loss: 0.0567 - val_accuracy: 0.5109 - val_loss: 1.4678
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9828 - loss: 0.0567 - val_accuracy: 0.6304 - val_loss: 0.9294
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9779 - loss: 0.0431 - val_accuracy: 0.7174 - val_loss: 0.9061
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9792 - loss: 0.0382 - val_accuracy: 0.9239 - val_loss: 0.3565
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9738 - loss: 0.0537 - val_accuracy: 0.9130 - val_loss: 0.3383
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9785 - loss: 0.0328 - val_accuracy: 0.9130 - val_loss: 0.2878
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9916 - loss: 0.0229 - val_accuracy: 0.9565 - val_loss: 0.1738
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9930 - loss: 0.0179 - val_accuracy: 0.9674 - val_loss: 0.1507
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9947 - loss: 0.0129 - val_accuracy: 0.9674 - val_loss: 0.1278
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9978 - loss: 0.0123 - val_accuracy: 0.9674 - val_loss: 0.0832
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9674 - val_loss: 0.0835
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9783 - val_loss: 0.0896
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9783 - val_loss: 0.0681
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9945 - loss: 0.0160 - val_accuracy: 0.9891 - val_loss: 0.0553
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9974 - loss: 0.0159 - val_accuracy: 0.9891 - val_loss: 0.0404
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9985 - loss: 0.0122 - val_accuracy: 0.9891 - val_loss: 0.0385
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9927 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0312
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9918 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0182
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9941 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9962 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9923 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9991 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9892 - loss: 0.0186 - val_accuracy: 0.9891 - val_loss: 0.0160
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9891 - val_loss: 0.0283
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 0.9891 - val_loss: 0.0258
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9885 - loss: 0.0079 - val_accuracy: 0.9891 - val_loss: 0.0171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step
#
# Test Accuracy: 0.9914
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        23
#            1       1.00      1.00      1.00        24
#            2       0.98      1.00      0.99        43
#            3       1.00      1.00      1.00        26
#
#     accuracy                           0.99       116
#    macro avg       0.99      0.99      0.99       116
# weighted avg       0.99      0.99      0.99       116

# %%
import numpy as np
import pandas as pd
import glob
import os
from tqdm import tqdm
from scipy.io import loadmat
from scipy.signal import periodogram
from scipy.stats import kurtosis, skew

# --- Config ---
sampling_rate = 12000
window_sec = 5
data_path = "/kaggle/input/bearing-data"

# --- Label Mapper ---
def classify_file(filename):
    if "IR" in filename: return "IR"
    if "OR" in filename: return "OR"
    if "B0" in filename: return "Ball"
    if "Normal" in filename or "97" in filename: return "Normal"
    return None

# --- Signal Segmenter ---
def segment_signal(signal, fs, window_sec):
    win_len = fs * window_sec
    return [signal[i:i+win_len] for i in range(0, len(signal), win_len) if len(signal[i:i+win_len]) == win_len]

# --- Feature Extractor ---
def extract_features(signal):
    rms = np.sqrt(np.mean(signal**2))
    k = kurtosis(signal)
    s = skew(signal)
    p2p = np.ptp(signal)
    crest = np.max(np.abs(signal)) / rms
    f, Pxx = periodogram(signal, sampling_rate)
    dom_freq = f[np.argmax(Pxx)]
    return {
        "rms": round(rms, 4),
        "kurtosis": round(k, 4),
        "skewness": round(s, 4),
        "peak_to_peak": round(p2p, 4),
        "crest_factor": round(crest, 4),
        "dominant_freq": int(dom_freq)
    }

# --- Format entry for embedding / RAG ---
def format_entry(features, label):
    return f"""Label: {label}
RMS: {features['rms']}, Kurtosis: {features['kurtosis']}, Skewness: {features['skewness']}, P2P: {features['peak_to_peak']}, Crest: {features['crest_factor']}, Dominant Freq: {features['dominant_freq']} Hz"""

# --- Process Dataset ---
entries = []
mat_files = glob.glob(os.path.join(data_path, "*.mat"))

for filepath in tqdm(mat_files):
    label = classify_file(os.path.basename(filepath))
    if label is None:
        continue

    try:
        data = loadmat(filepath)
        key = [k for k in data.keys() if "DE_time" in k][0]
        signal = data[key].ravel()
        segments = segment_signal(signal, sampling_rate, window_sec)

        for seg in segments:
            feats = extract_features(seg)
            formatted = format_entry(feats, label)
            entries.append(formatted)

    except Exception as e:
        print(f"❌ Error with {filepath}: {e}")

# --- Save to file ---
with open("bearing_fault_knowledge_base.txt", "w") as f:
    for line in entries:
        f.write(line + "\n\n")

print(f"✅ Knowledge base generated with {len(entries)} labeled segments.")
# Out:
# 100%|██████████| 62/62 [00:02<00:00, 21.13it/s]
# ✅ Knowledge base generated with 144 labeled segments.

# %%
from collections import defaultdict
import random

# Load original KB
with open("/kaggle/working/bearing_fault_knowledge_base.txt", "r") as f:
    blocks = f.read().strip().split("\n\n")

# Group by label
grouped = defaultdict(list)
for block in blocks:
    label_line = next((line for line in block.splitlines() if line.startswith("Label: ")), None)
    if label_line:
        label = label_line.split("Label: ")[1].strip()
        grouped[label].append(block)

# Find minimum count among all labels
min_count = min(len(v) for v in grouped.values())
print("Balanced sample count per class:", min_count)

# Sample equally and merge
balanced_blocks = []
for label, entries in grouped.items():
    balanced_blocks.extend(random.sample(entries, min_count))

# Save to a new file
with open("/kaggle/working/balanced_bearing_fault_knowledge_base2.txt", "w") as f:
    f.write("\n\n".join(balanced_blocks))
# Out:
# Balanced sample count per class: 28

# %%
# ✅ RAG-Enhanced Bearing Fault UI with CNN + Groq LLM (Balanced Knowledge Base) + CSV Logging

# !pip install ipywidgets faiss-cpu sentence-transformers --quiet

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.signal import spectrogram, periodogram
from scipy.stats import kurtosis, skew
import tensorflow as tf
import requests
import os
import glob
import ipywidgets as widgets
from IPython.display import display, clear_output
from sentence_transformers import SentenceTransformer
import faiss
import re
from datetime import datetime
from collections import defaultdict

# --- Config ---
sampling_rate = 12000
window_sec = 5
out_shape = (128, 128)
label_map = {0: "Normal", 1: "IR", 2: "OR", 3: "Ball"}
reverse_label_map = {v: k for k, v in label_map.items()}
groq_api_key = "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"  # 🔑 Insert your key safely
groq_url = "https://api.groq.com/openai/v1/chat/completions"
log_file_path = "/kaggle/working/prediction_log.csv"

# --- Load CNN Model ---
def load_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(128, 128, 1)),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D((2, 2)),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(4, activation='softmax')
    ])
    model.load_weights("/kaggle/working/bearing_fault_cnn_model_new.h5")
    return model

# --- Signal Processing ---
def segment_signal(signal, fs, window_sec):
    win_len = fs * window_sec
    return [signal[i:i+win_len] for i in range(0, len(signal), win_len) if len(signal[i:i+win_len]) == win_len]

def segment_to_spectrogram(segment, fs, out_shape):
    f, t, Sxx = spectrogram(segment, fs, nperseg=256, noverlap=128)
    Sxx_db = 10 * np.log10(Sxx + 1e-8)
    h, w = min(Sxx_db.shape[0], out_shape[0]), min(Sxx_db.shape[1], out_shape[1])
    out = np.zeros(out_shape)
    out[:h, :w] = Sxx_db[:h, :w]
    return out

def extract_features(signal):
    rms = np.sqrt(np.mean(signal**2))
    k = kurtosis(signal)
    s = skew(signal)
    p2p = np.ptp(signal)
    crest = np.max(np.abs(signal)) / rms
    f, Pxx = periodogram(signal, sampling_rate)
    dom_freq = f[np.argmax(Pxx)]
    return {
        "rms": round(rms, 4),
        "kurtosis": round(k, 4),
        "skewness": round(s, 4),
        "peak_to_peak": round(p2p, 4),
        "crest_factor": round(crest, 4),
        "dominant_freq": int(dom_freq)
    }

# --- Load and Index Balanced Knowledge Base ---
kb_path = "/kaggle/working/balanced_bearing_fault_knowledge_base2.txt"
with open(kb_path, "r") as f:
    raw_blocks = f.read().strip().split("\n\n")

texts = [block.replace("\n", " | ") for block in raw_blocks]
labels = [line.split("Label: ")[-1].split(" |")[0] for line in texts if "Label:" in line]

embedder = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedder.encode(texts, show_progress_bar=True)
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(np.array(embeddings))

# --- Retrieval ---
def retrieve_similar_cases(query_features, top_k=5):
    query_str = " | ".join([f"{k.capitalize()}: {v}" for k, v in query_features.items()])
    query_embedding = embedder.encode([query_str])
    D, I = index.search(query_embedding, top_k)
    return [texts[i] for i in I[0]], [labels[i] for i in I[0]]

def extract_fault_label(text):
    text = text.lower()
    if "inner race" in text or re.search(r"\b(ir|inner\s*race)\b", text): return "IR"
    if "outer race" in text or re.search(r"\b(or|outer\s*race)\b", text): return "OR"
    if "ball" in text: return "Ball"
    if "normal" in text: return "Normal"
    return "Unclear"


def query_llm_rag(features):
    prompt = f"""
You are a bearing fault diagnosis expert referring to ISO 13373-3 standards.

Use the following rules to classify faults:

- IR (Inner Race): Low kurtosis (<1), dominant frequency < 1000 Hz, moderate RMS, symmetric signal
- OR (Outer Race): High kurtosis (>3), high crest factor, RMS > 0.5, dominant frequency 500–2000 Hz
- Ball Fault: Moderate kurtosis (1–2.5), crest factor around 4–5, dominant frequency > 1200 Hz
- Normal: Low RMS (<0.3), low kurtosis (<1), crest factor around 3–4

New signal features:
- RMS: {features['rms']}
- Kurtosis: {features['kurtosis']}
- Skewness: {features['skewness']}
- Peak-to-Peak: {features['peak_to_peak']}
- Crest Factor: {features['crest_factor']}
- Dominant Frequency: {features['dominant_freq']} Hz

Return only one word: Normal, IR, OR, or Ball.
"""

    headers = {"Authorization": f"Bearer {groq_api_key}", "Content-Type": "application/json"}
    payload = {
        "model": "llama3-70b-8192",
        "messages": [
            {"role": "system", "content": "You are a bearing fault diagnosis expert."},
            {"role": "user", "content": prompt}
        ]
    }

    try:
        r = requests.post(groq_url, headers=headers, json=payload)
        r.raise_for_status()
        resp = r.json()
        raw = resp.get("choices", [{}])[0].get("message", {}).get("content", "Unclear").strip()
        print("🔍 Raw LLM Response:", raw)
        return extract_fault_label(raw)
    except Exception as e:
        print("❌ Groq Exception:", e)
        return "LLM ERROR"


# --- CSV Logging ---
def log_to_csv(file_name, llm_pred, cnn_pred, confidence, features):
    df = pd.DataFrame([{
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "file": file_name,
        "llm_prediction": llm_pred,
        "cnn_prediction": cnn_pred,
        "cnn_confidence": confidence,
        **features
    }])
    if not os.path.exists(log_file_path):
        df.to_csv(log_file_path, index=False)
    else:
        df.to_csv(log_file_path, mode='a', header=False, index=False)

# --- Prediction Pipeline ---
output_area = widgets.Output()

def predict(file_path):
    with output_area:
        clear_output()
        print(f"📂 Processing file: {os.path.basename(file_path)}")

        try:
            mat = loadmat(file_path)
            key = [k for k in mat if "DE_time" in k][0]
            signal = mat[key].ravel()
            segments = segment_signal(signal, sampling_rate, window_sec)
            if not segments:
                print("❌ No valid 5-second segment found.")
                return

            segment = segments[0]
            spec = segment_to_spectrogram(segment, sampling_rate, out_shape)
            model = load_model()
            pred = model.predict(np.expand_dims(spec, axis=(0, -1)))[0]
            cnn_pred = label_map[np.argmax(pred)]
            cnn_conf = float(np.max(pred))

            features = extract_features(segment)
            llm_pred = query_llm_rag(features)

            print(f"\n🧠 LLM (Groq) Prediction: {llm_pred}")
            print(f"🤖 CNN Prediction: {cnn_pred} ({cnn_conf:.2%})")
            print("📊 Extracted Features:", features)
            print("✅" if llm_pred.upper() == cnn_pred.upper() else "⚠️ Models disagree.")

            log_to_csv(os.path.basename(file_path), llm_pred, cnn_pred, cnn_conf, features)

            plt.figure(figsize=(10, 3))
            plt.plot(segment[:2000])
            plt.title("First 2000 points of vibration segment")
            plt.xlabel("Time")
            plt.ylabel("Amplitude")
            plt.grid(True)
            plt.show()

        except Exception as e:
            print("❌ Error during prediction:", e)

# --- UI ---
mat_files = sorted(glob.glob("/kaggle/input/testing/**/*.mat", recursive=True) +
                   glob.glob("/kaggle/input/inference/**/*.mat", recursive=True) +
                   glob.glob("/kaggle/input/test-final/**/*.mat", recursive=True) +
                   glob.glob("/kaggle/input/bearing-data/**/*.mat", recursive=True))

dropdown = widgets.Dropdown(
    options=[(f"{os.path.basename(os.path.dirname(f))} ➜ {os.path.basename(f)}", f) for f in mat_files],
    description='Select .mat:',
    layout=widgets.Layout(width='90%')
)

button = widgets.Button(description="Run Prediction", button_style='success')
button.on_click(lambda b: predict(dropdown.value))

display(dropdown, button, output_area)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Dropdown(description='Select .mat:', layout=Layout(width='90%'), options=(('bearing-data ➜ B007_0.mat', '/kagg…
# Button(button_style='success', description='Run Prediction', style=ButtonStyle())
# Output()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import spectrogram

# --- Augmentations (Exaggerated for Visuals) ---
def add_rms_scaled_noise(signal, noise_ratio=0.2):
    rms = np.sqrt(np.mean(signal**2))
    noise = np.random.normal(0, noise_ratio * rms, size=signal.shape)
    return signal + noise

def amplitude_scaling(signal, scale_range=(0.4, 2.0)):
    scale = np.random.uniform(*scale_range)
    return signal * scale

def frequency_masking(spec, num_masks=1, freq_masking_max_percentage=0.15):
    spec = spec.copy()
    num_freqs = spec.shape[0]
    for _ in range(num_masks):
        f = int(np.random.uniform(0.1, freq_masking_max_percentage) * num_freqs)
        f0 = np.random.randint(0, num_freqs - f)
        spec[f0:f0 + f, :] = 0
    return spec

def segment_to_spectrogram(segment, fs=12000, out_shape=(128, 128)):
    f, t, Sxx = spectrogram(segment, fs, nperseg=256, noverlap=128)
    Sxx_db = 10 * np.log10(Sxx + 1e-8)
    h, w = min(Sxx_db.shape[0], out_shape[0]), min(Sxx_db.shape[1], out_shape[1])
    out = np.zeros(out_shape)
    out[:h, :w] = Sxx_db[:h, :w]
    return out

# === Generate Variants ===
noisy_segment = add_rms_scaled_noise(sample_segment)
scaled_segment = amplitude_scaling(sample_segment)

spec_orig = segment_to_spectrogram(sample_segment)
spec_noisy = segment_to_spectrogram(noisy_segment)
spec_scaled = segment_to_spectrogram(scaled_segment)
spec_masked = frequency_masking(spec_orig)

# === Raw Signal Comparison: Original vs Noisy ===
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(sample_segment[10000:10500], color='black', label='Original')
plt.title("Raw Signal: Original")
plt.xlabel("Time")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(noisy_segment[10000:10500], color='red', label='Noisy')
plt.title("Raw Signal: Gaussian Noise Added ")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.tight_layout()
plt.show()

# === Raw Signal Comparison: Original vs Amplitude Scaled ===
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(sample_segment[10000:10500], color='black')
plt.title("Raw Signal: Original")
plt.xlabel("Time")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(scaled_segment[10000:10500], color='orange')
plt.title("Raw Signal: Amplitude Scaled ")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.tight_layout()
plt.show()

# === Spectrogram: Original vs Gaussian Noise ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(spec_orig, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Original")
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(spec_noisy, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Gaussian Noise ")
plt.colorbar()
plt.tight_layout()
plt.show()

# === Spectrogram: Original vs Amplitude Scaled ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(spec_orig, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Original")
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(spec_scaled, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Amplitude Scaled ")
plt.colorbar()
plt.tight_layout()
plt.show()

# === Spectrogram: Original vs Frequency Masked ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(spec_orig, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Original")
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(spec_masked, aspect='auto', origin='lower', cmap='inferno', vmin=-100, vmax=0)
plt.title("Spectrogram: Frequency Masked (Aggressive)")
plt.colorbar()
plt.tight_layout()
plt.show()
